# %%
import gzip
import numpy as np
import os
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow.compat.v1 as tf

import adversarial_debiasing_model
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_spec(name, path, target)
#
# AttributeError: 'NotebookFinder' object has no attribute 'find_spec'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-9695fa877fdc> in <module>
#      10 import tensorflow.compat.v1 as tf
#      11
# ---> 12 import adversarial_debiasing_model
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_spec(name, path, target)
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_spec_legacy(finder, name, path)
#
# <ipython-input-79-c744310e3ecb> in find_module(self, fullname, path)
#      47
#      48     def find_module(self, fullname, path=None):
# ---> 49         nb_path = find_notebook(fullname, path)
#      50         if not nb_path:
#      51             return
#
# NameError: name 'find_notebook' is not defined

# %%
ls nbpackage
# Out:
# ls: nbpackage: No such file or directory

# %%
def get_data(filename):
    return pd.read_csv(filename) 

def split_train_test(compas_df, train=0.75):
    shuffled = np.random.RandomState(0).permutation(compas_df.index)
    n_train = int(len(shuffled) * train)
    i_train, i_test = shuffled[:n_train], shuffled[n_train:]
    return compas_df.loc[i_train], compas_df.loc[i_test]

def process_data(df, drop_columns, label_column, protect_column):
    df = df.drop(columns=drop_columns, axis=1)
    feature_columns = set(df.columns) - {label_column, protect_column}
    features = df[list(feature_columns)].values
    labels = df[label_column].values.reshape(-1,1)
    protect = df[protect_column].values.reshape(-1,1)
    return (features, labels, protect)

# %%
data = compas_df[['is_recid','race_African-American','race_Caucasian','juv_fel_count', 'juv_misd_count', 'juv_other_count', 'priors_count',
       'decile_score',  'is_violent_recid', 'sex_Female', 'sex_Male', 'age_cat_25 - 45',
       'age_cat_Greater than 45', 'age_cat_Less than 25', 'jail_stay_length']]

# %%
# whites = data[data['race_Caucasian'] == 1]
# whites.drop(columns=['race_African-American','race_Caucasian'], inplace=True)
# whites.corr()

# %%
fig, ax = plt.subplots(figsize=(10,7))
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True,
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
